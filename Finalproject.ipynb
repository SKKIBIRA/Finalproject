# %%
import pandas as pd

# %%
df1 = pd.read_csv('2015_16_Statewise_Elementary.csv')
df1
# Out:
#     AC_YEAR  STATCD              STATNAME  DISTRICTS  BLOCKS  VILLAGES  \
# 0   2015-16       1       JAMMU & KASHMIR         22     201      7263
# 1   2015-16       2      HIMACHAL PRADESH         12     124     10120
# 2   2015-16       3                PUNJAB         22     146     13197
# 3   2015-16       4            CHANDIGARH          1      20        84
# 4   2015-16       5           UTTARAKHAND         13      95     11989
# 5   2015-16       6               HARYANA         21     126      7438
# 6   2015-16       7                 DELHI          9      69      1201
# 7   2015-16       8             RAJASTHAN         33     302     41441
# 8   2015-16       9         UTTAR PRADESH         75     971     98470
# 9   2015-16      10                 BIHAR         38     537     40779
# 10  2015-16      11                SIKKIM          4      29       756
# 11  2015-16      12     ARUNACHAL PRADESH         20      99      2982
# ...

# %%
df2 = pd.read_csv('2015_16_Statewise_Secondary.csv')
df2
# Out:
#     ac_year  statcd                        statname  area_sqkm  \
# 0   2015-16       1               Jammu And Kashmir   222236.0
# 1   2015-16       2                Himachal Pradesh    55673.0
# 2   2015-16       3                          Punjab    50362.0
# 3   2015-16       4                      Chandigarh      114.0
# 4   2015-16       5                     Uttarakhand    53483.0
# 5   2015-16       6                         Haryana    44212.0
# 6   2015-16       7  Delhi                              1483.0
# 7   2015-16       8  Rajasthan                        342239.0
# 8   2015-16       9                   Uttar Pradesh   240928.0
# 9   2015-16      10                           Bihar    94163.0
# 10  2015-16      11                          Sikkim     7096.0
# 11  2015-16      12               Arunachal Pradesh    83743.0
# 12  2015-16      13                        Nagaland    16579.0
# 13  2015-16      14                         Manipur    22327.0
# ...

# %%
df2 = pd.read_csv('2015_16_Statewise_Secondary.csv')
df2
# Out:
#     ac_year  statcd                        statname  area_sqkm  \
# 0   2015-16       1               Jammu And Kashmir   222236.0
# 1   2015-16       2                Himachal Pradesh    55673.0
# 2   2015-16       3                          Punjab    50362.0
# 3   2015-16       4                      Chandigarh      114.0
# 4   2015-16       5                     Uttarakhand    53483.0
# 5   2015-16       6                         Haryana    44212.0
# 6   2015-16       7  Delhi                              1483.0
# 7   2015-16       8  Rajasthan                        342239.0
# 8   2015-16       9                   Uttar Pradesh   240928.0
# 9   2015-16      10                           Bihar    94163.0
# 10  2015-16      11                          Sikkim     7096.0
# 11  2015-16      12               Arunachal Pradesh    83743.0
# 12  2015-16      13                        Nagaland    16579.0
# 13  2015-16      14                         Manipur    22327.0
# ...

# %%
df3 = pd.concat([df1, df2], axis=1)
df3
# Out:
#     AC_YEAR  STATCD              STATNAME  DISTRICTS  BLOCKS  VILLAGES  \
# 0   2015-16       1       JAMMU & KASHMIR         22     201      7263
# 1   2015-16       2      HIMACHAL PRADESH         12     124     10120
# 2   2015-16       3                PUNJAB         22     146     13197
# 3   2015-16       4            CHANDIGARH          1      20        84
# 4   2015-16       5           UTTARAKHAND         13      95     11989
# 5   2015-16       6               HARYANA         21     126      7438
# 6   2015-16       7                 DELHI          9      69      1201
# 7   2015-16       8             RAJASTHAN         33     302     41441
# 8   2015-16       9         UTTAR PRADESH         75     971     98470
# 9   2015-16      10                 BIHAR         38     537     40779
# 10  2015-16      11                SIKKIM          4      29       756
# 11  2015-16      12     ARUNACHAL PRADESH         20      99      2982
# ...

# %%
df3.head()
# Out:
#    AC_YEAR  STATCD          STATNAME  DISTRICTS  BLOCKS  VILLAGES  CLUSTERS  \
# 0  2015-16       1   JAMMU & KASHMIR         22     201      7263      1628
# 1  2015-16       2  HIMACHAL PRADESH         12     124     10120      2243
# 2  2015-16       3            PUNJAB         22     146     13197      1780
# 3  2015-16       4        CHANDIGARH          1      20        84        20
# 4  2015-16       5       UTTARAKHAND         13      95     11989       995
#
#    TOTPOPULAT  P_URB_POP  POPULATION_0_6  ...  tchmed_nr  tchoth_nr  tchse_nr  \
# 0       12549      20.05           16.01  ...          0          0         0
# 1        6857       8.69           11.14  ...          0          0         0
# 2       27704      29.82           10.62  ...          0          0         0
# 3        1055      97.25           11.18  ...          0          0         0
# 4       10117      21.54           13.14  ...          0          0         0
#
# ...

# %%
df3.tail()
# Out:
#     AC_YEAR  STATCD       STATNAME  DISTRICTS  BLOCKS  VILLAGES  CLUSTERS  \
# 31  2015-16      32         KERALA         14     166      1907      1375
# 32  2015-16      33     TAMIL NADU         30     413     19301      4092
# 33  2015-16      34     PUDUCHERRY          4       6       145        33
# 34  2015-16      35  A & N ISLANDS          3       9       198        37
# 35  2015-16      36      TELANGANA         10     459      9934      1776
#
#     TOTPOPULAT  P_URB_POP  POPULATION_0_6  ...  tchmed_nr  tchoth_nr  \
# 31       33388      24.76            9.95  ...          0          0
# 32       72139      38.10            9.56  ...          0          0
# 33        1244      52.12           10.25  ...          0          0
# 34         380      30.58           10.40  ...          0          0
# 35         352      38.67           39.20  ...          0          0
#
#     tchse_nr  tchnr_nr  enrc7_py  enrc8_py  enrc9_py  enrc10_py  enr11_py  \
# ...

# %%
df3.shape
# Out:
# (36, 1446)

# %%
df3.describe
# Out:
# <bound method NDFrame.describe of     AC_YEAR  STATCD              STATNAME  DISTRICTS  BLOCKS  VILLAGES  \
# 0   2015-16       1       JAMMU & KASHMIR         22     201      7263
# 1   2015-16       2      HIMACHAL PRADESH         12     124     10120
# 2   2015-16       3                PUNJAB         22     146     13197
# 3   2015-16       4            CHANDIGARH          1      20        84
# 4   2015-16       5           UTTARAKHAND         13      95     11989
# 5   2015-16       6               HARYANA         21     126      7438
# 6   2015-16       7                 DELHI          9      69      1201
# 7   2015-16       8             RAJASTHAN         33     302     41441
# 8   2015-16       9         UTTAR PRADESH         75     971     98470
# 9   2015-16      10                 BIHAR         38     537     40779
# 10  2015-16      11                SIKKIM          4      29       756
# 11  2015-16      12     ARUNACHAL PRADESH         20      99      2982
# ...

# %%
df3.columns
# Out:
# Index(['AC_YEAR', 'STATCD', 'STATNAME', 'DISTRICTS', 'BLOCKS', 'VILLAGES',
#        'CLUSTERS', 'TOTPOPULAT', 'P_URB_POP', 'POPULATION_0_6',
#        ...
#        'tchmed_nr', 'tchoth_nr', 'tchse_nr', 'tchnr_nr', 'enrc7_py',
#        'enrc8_py', 'enrc9_py', 'enrc10_py', 'enr11_py', 'enr12_py'],
#       dtype='object', length=1446)

# %%
#Data types illustrated

# %%
df3.dtypes
# Out:
# AC_YEAR      object
# STATCD        int64
# STATNAME     object
# DISTRICTS     int64
# BLOCKS        int64
#               ...
# enrc8_py      int64
# enrc9_py      int64
# enrc10_py     int64
# enr11_py      int64
# enr12_py      int64
# Length: 1446, dtype: object

# %%
#Illustrating duplicating data

# %%
df3.duplicated
# Out:
# <bound method DataFrame.duplicated of     AC_YEAR  STATCD              STATNAME  DISTRICTS  BLOCKS  VILLAGES  \
# 0   2015-16       1       JAMMU & KASHMIR         22     201      7263
# 1   2015-16       2      HIMACHAL PRADESH         12     124     10120
# 2   2015-16       3                PUNJAB         22     146     13197
# 3   2015-16       4            CHANDIGARH          1      20        84
# 4   2015-16       5           UTTARAKHAND         13      95     11989
# 5   2015-16       6               HARYANA         21     126      7438
# 6   2015-16       7                 DELHI          9      69      1201
# 7   2015-16       8             RAJASTHAN         33     302     41441
# 8   2015-16       9         UTTAR PRADESH         75     971     98470
# 9   2015-16      10                 BIHAR         38     537     40779
# 10  2015-16      11                SIKKIM          4      29       756
# 11  2015-16      12     ARUNACHAL PRADESH         20      99      2982
# ...

# %%
#Obtaining the missing values

# %%
df3.isnull().sum()
# Out:
# AC_YEAR      0
# STATCD       0
# STATNAME     0
# DISTRICTS    0
# BLOCKS       0
#             ..
# enrc8_py     0
# enrc9_py     0
# enrc10_py    0
# enr11_py     0
# enr12_py     0
# Length: 1446, dtype: int64

# %%
There are no missing values in the dataset

# %%
df3.nunique()
# Out:
# AC_YEAR       1
# STATCD       36
# STATNAME     36
# DISTRICTS    23
# BLOCKS       35
#              ..
# enrc8_py     36
# enrc9_py     36
# enrc10_py    36
# enr11_py     36
# enr12_py     36
# Length: 1446, dtype: int64

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df3
# Out:
#     AC_YEAR  STATCD              STATNAME  DISTRICTS  BLOCKS  VILLAGES  \
# 0   2015-16       1       JAMMU & KASHMIR         22     201      7263
# 1   2015-16       2      HIMACHAL PRADESH         12     124     10120
# 2   2015-16       3                PUNJAB         22     146     13197
# 3   2015-16       4            CHANDIGARH          1      20        84
# 4   2015-16       5           UTTARAKHAND         13      95     11989
# 5   2015-16       6               HARYANA         21     126      7438
# 6   2015-16       7                 DELHI          9      69      1201
# 7   2015-16       8             RAJASTHAN         33     302     41441
# 8   2015-16       9         UTTAR PRADESH         75     971     98470
# 9   2015-16      10                 BIHAR         38     537     40779
# 10  2015-16      11                SIKKIM          4      29       756
# 11  2015-16      12     ARUNACHAL PRADESH         20      99      2982
# ...

# %%
#The columns for the data set are iluustrated as follows;

# %%
df3.columns
# Out:
# Index(['STATCD', 'STATNAME', 'DISTRICTS', 'BLOCKS', 'VILLAGES', 'CLUSTERS',
#        'TOTPOPULAT', 'P_URB_POP', 'POPULATION_0_6', 'GROWTHRATE',
#        ...
#        'tchmed_nr', 'tchoth_nr', 'tchse_nr', 'tchnr_nr', 'enrc7_py',
#        'enrc8_py', 'enrc9_py', 'enrc10_py', 'enr11_py', 'enr12_py'],
#       dtype='object', length=1445)

# %% [markdown]
# # Random sampling of various grades(elementary and secondary) in the illustrations shown below

# %%
df3['DISTRICTS'].value_counts() \
    .head(10) \
    .plot(kind='bar', title='Districts count')
# Out:
# <Axes: title={'center': 'Districts count'}, xlabel='DISTRICTS'>

# %%
df3['VILLAGES'].plot(kind='hist', bins=20, title='Villages across states')
# Out:
# <Axes: title={'center': 'Villages across states'}, ylabel='Frequency'>

# %%
#Histogram illustrating the total population

# %%
df3['TOTPOPULAT'].plot(kind='hist', bins=20, title='Total population')
# Out:
# <Axes: title={'center': 'Total population'}, ylabel='Frequency'>

# %%
df3.plot(kind='scatter', x='STATNAME', y='enrc9_py')
plt.show()

# %%
# Histogram illustrating the elementary grade 6

# %%
df3['enrc7_py'].plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
# The scatter plot illustrates the relationship between the state and elementary grade 9

# %%
sns.scatterplot(x='STATNAME', y='enrc9_py', data=df3)
# Out:
# <Axes: xlabel='STATNAME', ylabel='enrc9_py'>

# %%
#Relationship between variables in the dataset

# %%
sns.pairplot(df3, vars=['VILLAGES', 'TOTPOPULAT', 'enrc7_py', 'enrc8_py', 'enrc9_py'])
plt.show()
# Out:
# C:\Users\User\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\User\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\User\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %% [markdown]
# # The above plots and bargraphs shows the distribution of both elementary and secondary learners across villages and their total population.

# %%
# The operation to drop the column with states

# %%
import pandas as pd
df1 = pd.read_csv('2015_16_Statewise_Elementary.csv')
df2 = pd.read_csv('2015_16_Statewise_Secondary.csv')
df3 = pd.concat([df1, df2], axis = 1)
df3.drop(['STATNAME'], axis = 1)
# Out:
#     AC_YEAR  STATCD  DISTRICTS  BLOCKS  VILLAGES  CLUSTERS  TOTPOPULAT  \
# 0   2015-16       1         22     201      7263      1628       12549
# 1   2015-16       2         12     124     10120      2243        6857
# 2   2015-16       3         22     146     13197      1780       27704
# 3   2015-16       4          1      20        84        20        1055
# 4   2015-16       5         13      95     11989       995       10117
# 5   2015-16       6         21     126      7438      1523       25353
# 6   2015-16       7          9      69      1201        69       16753
# 7   2015-16       8         33     302     41441     10594       68621
# 8   2015-16       9         75     971     98470      9423      199581
# 9   2015-16      10         38     537     40779      5633      103805
# 10  2015-16      11          4      29       756       111         608
# 11  2015-16      12         20      99      2982       234        1383
# ...

# %%
# A new data frame is created after dropping the state names

# %%
df4 = df3.drop(['STATNAME'], axis = 1)
df4
# Out:
#     STATCD  DISTRICTS  BLOCKS  VILLAGES  CLUSTERS  TOTPOPULAT  P_URB_POP  \
# 0        1         22     201      7263      1628       12549      20.05
# 1        2         12     124     10120      2243        6857       8.69
# 2        3         22     146     13197      1780       27704      29.82
# 3        4          1      20        84        20        1055      97.25
# 4        5         13      95     11989       995       10117      21.54
# 5        6         21     126      7438      1523       25353      24.12
# 6        7          9      69      1201        69       16753      77.03
# 7        8         33     302     41441     10594       68621      19.26
# 8        9         75     971     98470      9423      199581      17.31
# 9       10         38     537     40779      5633      103805       8.36
# 10      11          4      29       756       111         608       9.85
# 11      12         20      99      2982       234        1383      16.48
# ...

# %%
df4.head()
# Out:
#    STATCD  DISTRICTS  BLOCKS  VILLAGES  CLUSTERS  TOTPOPULAT  P_URB_POP  \
# 0       1         22     201      7263      1628       12549      20.05
# 1       2         12     124     10120      2243        6857       8.69
# 2       3         22     146     13197      1780       27704      29.82
# 3       4          1      20        84        20        1055      97.25
# 4       5         13      95     11989       995       10117      21.54
#
#    POPULATION_0_6  GROWTHRATE  SEXRATIO  ...  tchmed_nr  tchoth_nr  tchse_nr  \
# 0           16.01       23.71       883  ...          0          0         0
# 1           11.14       12.81       974  ...          0          0         0
# 2           10.62       13.73       893  ...          0          0         0
# 3           11.18       17.10       818  ...          0          0         0
# 4           13.14       19.17       963  ...          0          0         0
#
# ...

# %%
df4.describe()
# Out:
#           STATCD  DISTRICTS      BLOCKS      VILLAGES      CLUSTERS  \
# count  36.000000  36.000000   36.000000     36.000000     36.000000
# mean   18.500000  18.888889  203.250000  16520.500000   2289.833333
# std    10.535654  15.947732  220.756928  21166.739773   2645.161756
# min     1.000000   1.000000    1.000000     10.000000      7.000000
# 25%     9.750000   8.000000   35.750000   1038.500000    121.500000
# 50%    18.500000  13.500000  135.500000   8686.000000   1575.500000
# 75%    27.250000  27.750000  306.250000  23341.000000   3865.000000
# max    36.000000  75.000000  971.000000  98470.000000  10594.000000
#
#           TOTPOPULAT  P_URB_POP  POPULATION_0_6  GROWTHRATE     SEXRATIO  ...  \
# count      36.000000  36.000000       36.000000   36.000000    36.000000  ...
# mean    58626.333333  27.678889       13.480556   19.990556   930.888889  ...
# std    165584.055709  18.354991        5.006451   11.455856    79.126581  ...
# ...

# %%
df4.dtypes
# Out:
# STATCD       int64
# DISTRICTS    int64
# BLOCKS       int64
# VILLAGES     int64
# CLUSTERS     int64
#              ...
# enrc8_py     int64
# enrc9_py     int64
# enrc10_py    int64
# enr11_py     int64
# enr12_py     int64
# Length: 1444, dtype: object

# %%
df3 = pd.concat([df1, df2], axis = 1)
df4 = df3.drop(['STATNAME'], axis=1)
df4.select_dtypes(include=['number'])
df4
# Out:
#     AC_YEAR  STATCD  DISTRICTS  BLOCKS  VILLAGES  CLUSTERS  TOTPOPULAT  \
# 0   2015-16       1         22     201      7263      1628       12549
# 1   2015-16       2         12     124     10120      2243        6857
# 2   2015-16       3         22     146     13197      1780       27704
# 3   2015-16       4          1      20        84        20        1055
# 4   2015-16       5         13      95     11989       995       10117
# 5   2015-16       6         21     126      7438      1523       25353
# 6   2015-16       7          9      69      1201        69       16753
# 7   2015-16       8         33     302     41441     10594       68621
# 8   2015-16       9         75     971     98470      9423      199581
# 9   2015-16      10         38     537     40779      5633      103805
# 10  2015-16      11          4      29       756       111         608
# 11  2015-16      12         20      99      2982       234        1383
# ...

# %%
import pandas as pd
df1 = pd.read_csv('2015_16_Statewise_Elementary.csv')
df2 = pd.read_csv('2015_16_Statewise_Secondary.csv')
df3 = pd.concat([df1, df2], axis = 1)
df4 = df3.drop(['AC_YEAR'], axis = 1)
df4
# Out:
#     STATCD              STATNAME  DISTRICTS  BLOCKS  VILLAGES  CLUSTERS  \
# 0        1       JAMMU & KASHMIR         22     201      7263      1628
# 1        2      HIMACHAL PRADESH         12     124     10120      2243
# 2        3                PUNJAB         22     146     13197      1780
# 3        4            CHANDIGARH          1      20        84        20
# 4        5           UTTARAKHAND         13      95     11989       995
# 5        6               HARYANA         21     126      7438      1523
# 6        7                 DELHI          9      69      1201        69
# 7        8             RAJASTHAN         33     302     41441     10594
# 8        9         UTTAR PRADESH         75     971     98470      9423
# 9       10                 BIHAR         38     537     40779      5633
# 10      11                SIKKIM          4      29       756       111
# 11      12     ARUNACHAL PRADESH         20      99      2982       234
# ...

# %%
df5 = df4.drop(['STATNAME'], axis = 1)
df5
# Out:
#     STATCD  DISTRICTS  BLOCKS  VILLAGES  CLUSTERS  TOTPOPULAT  P_URB_POP  \
# 0        1         22     201      7263      1628       12549      20.05
# 1        2         12     124     10120      2243        6857       8.69
# 2        3         22     146     13197      1780       27704      29.82
# 3        4          1      20        84        20        1055      97.25
# 4        5         13      95     11989       995       10117      21.54
# 5        6         21     126      7438      1523       25353      24.12
# 6        7          9      69      1201        69       16753      77.03
# 7        8         33     302     41441     10594       68621      19.26
# 8        9         75     971     98470      9423      199581      17.31
# 9       10         38     537     40779      5633      103805       8.36
# 10      11          4      29       756       111         608       9.85
# 11      12         20      99      2982       234        1383      16.48
# ...

# %% [markdown]
# # The dataframe below illustrates the data type whether object or numbers as shown below

# %%
df5.select_dtypes(include = ['object'])
# Out:
#     ac_year                        statname
# 0   2015-16               Jammu And Kashmir
# 1   2015-16                Himachal Pradesh
# 2   2015-16                          Punjab
# 3   2015-16                      Chandigarh
# 4   2015-16                     Uttarakhand
# 5   2015-16                         Haryana
# 6   2015-16  Delhi
# 7   2015-16  Rajasthan
# 8   2015-16                   Uttar Pradesh
# 9   2015-16                           Bihar
# 10  2015-16                          Sikkim
# 11  2015-16               Arunachal Pradesh
# 12  2015-16                        Nagaland
# 13  2015-16                         Manipur
# 14  2015-16  Mizoram
# 15  2015-16                         Tripura
# 16  2015-16  Meghalaya
# 17  2015-16                           Assam
# 18  2015-16  West Bengal
# 19  2015-16                       Jharkhand
# 20  2015-16                          Odisha
# 21  2015-16                    Chhattisgarh
# 22  2015-16                  MADHYA PRADESH
# ...

# %%
df5.select_dtypes(include = ['number'])
# Out:
#     STATCD  DISTRICTS  BLOCKS  VILLAGES  CLUSTERS  TOTPOPULAT  P_URB_POP  \
# 0        1         22     201      7263      1628       12549      20.05
# 1        2         12     124     10120      2243        6857       8.69
# 2        3         22     146     13197      1780       27704      29.82
# 3        4          1      20        84        20        1055      97.25
# 4        5         13      95     11989       995       10117      21.54
# 5        6         21     126      7438      1523       25353      24.12
# 6        7          9      69      1201        69       16753      77.03
# 7        8         33     302     41441     10594       68621      19.26
# 8        9         75     971     98470      9423      199581      17.31
# 9       10         38     537     40779      5633      103805       8.36
# 10      11          4      29       756       111         608       9.85
# 11      12         20      99      2982       234        1383      16.48
# ...

# %%
df5.corr
# Out:
# <bound method DataFrame.corr of     ac_year  statcd                        statname  area_sqkm  \
# 0   2015-16       1               Jammu And Kashmir   222236.0
# 1   2015-16       2                Himachal Pradesh    55673.0
# 2   2015-16       3                          Punjab    50362.0
# 3   2015-16       4                      Chandigarh      114.0
# 4   2015-16       5                     Uttarakhand    53483.0
# 5   2015-16       6                         Haryana    44212.0
# 6   2015-16       7  Delhi                              1483.0
# 7   2015-16       8  Rajasthan                        342239.0
# 8   2015-16       9                   Uttar Pradesh   240928.0
# 9   2015-16      10                           Bihar    94163.0
# 10  2015-16      11                          Sikkim     7096.0
# 11  2015-16      12               Arunachal Pradesh    83743.0
# 12  2015-16      13                        Nagaland    16579.0
# ...

# %%
import pandas as pd
import seaborn as sns
df5.dtypes
# Out:
# ac_year            object
# statcd              int64
# statname           object
# area_sqkm         float64
# tot_population    float64
#                    ...
# TOTCLS3G            int64
# TOTCLS4G            int64
# TOTCLS5G            int64
# TOTCLS6G            int64
# TOTCLS7G            int64
# Length: 1444, dtype: object

# %%
df5 = df4.drop(['STATNAME'], axis = 1)
df5
# Out:
#     STATCD  DISTRICTS  BLOCKS  VILLAGES  CLUSTERS  TOTPOPULAT  P_URB_POP  \
# 0        1         22     201      7263      1628       12549      20.05
# 1        2         12     124     10120      2243        6857       8.69
# 2        3         22     146     13197      1780       27704      29.82
# 3        4          1      20        84        20        1055      97.25
# 4        5         13      95     11989       995       10117      21.54
# 5        6         21     126      7438      1523       25353      24.12
# 6        7          9      69      1201        69       16753      77.03
# 7        8         33     302     41441     10594       68621      19.26
# 8        9         75     971     98470      9423      199581      17.31
# 9       10         38     537     40779      5633      103805       8.36
# 10      11          4      29       756       111         608       9.85
# 11      12         20      99      2982       234        1383      16.48
# ...

# %%
#Creating a box plot

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
ax = df5.boxplot(column= "STATCD", by="GROWTHRATE", figsize=(20,10))
ax.set_ylabel("STATCD")
ax.set_title("")
# Out:
# Text(0.5, 1.0, '')

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
ax = df5.boxplot(column= "VILLAGES", by="GROWTHRATE", figsize=(20,10))
ax.set_ylabel("VILLAGES")
ax.set_title("")
# Out:
# Text(0.5, 1.0, '')

# %%
#Heatmap to show correlation

# %%
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
sns.boxplot(y="SEXRATIO", data= df5)
plt.show()

# %%
sns.boxplot(y="enrc10_py", data= df5)
# Out:
# <Axes: ylabel='enrc10_py'>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import scipy.stats as stats
import math
np.random.seed(6)
